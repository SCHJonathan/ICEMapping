# %%
from math import radians, cos, sin, asin, sqrt
import pandas as pd
import MySQLdb

db = MySQLdb.connect(host="127.0.0.1",  
                     user="root",         
                     passwd="database", 
                     db="cs411") 

engin = [-88.227240, 40.113910]
main = [-88.227240, 40.107936]
south = [-88.230845, 40.102291]

def distance(part):
    cur = db.cursor()
    cur.execute('SELECT * FROM tidychampaign')
    champaign = pd.read_sql('SELECT GEOID, Block FROM tidychampaign', con=db)
    geo = pd.read_sql('SELECT GEOID, lon, lat FROM geo', con=db)
    data = pd.merge(geo, champaign,
                    on='GEOID',
                    how='inner')
    dis = list(range(len(data)))
    for i in range(len(data)):        
        lon1, lat1, lon2, lat2 = map(radians, [part[0], part[1], data['lon'][i], data['lat'][i]])
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a))
        r = 6371
        dis[i] = c * r
        data['distance'] = dis
    return data

# %%
distance(main)
# Out:
#                 GEOID        lon        lat       Block  distance
# 0     170190060001042 -88.212946  40.090914  Block 1042  2.249593
# 1     170190057013017 -88.207146  40.087803  Block 3017  2.816568
# 2     170190057011010 -88.201870  40.095596  Block 1010  2.557165
# 3     170190057011011 -88.202466  40.095580  Block 1011  2.515520
# 4     170190056004002 -88.202909  40.103358  Block 4002  2.130985
# 5     170190055001036 -88.203163  40.111034  Block 1036  2.076395
# 6     170190055004036 -88.200772  40.107899  Block 4036  2.251005
# 7     170190055004035 -88.199665  40.107910  Block 4035  2.345139
# 8     170190057014006 -88.200650  40.088799  Block 4006  3.105378
# 9     170190055004040 -88.198503  40.107920  Block 4040  2.443952
# 10    170190054021005 -88.196975  40.138984  Block 1005  4.305955
# 11    170190054021003 -88.191671  40.140152  Block 1003  4.688096
# 12    170190055004006 -88.194873  40.111702  Block 4006  2.784275
# 13    170190055004020 -88.195428  40.108564  Block 4020  2.706373
# 14    170190055004018 -88.194217  40.108570  Block 4018  2.809319
# 15    170190057012001 -88.192085  40.094282  Block 2001  3.353469
# 16    170190057012002 -88.193741  40.094279  Block 2002  3.228669
# 17    170190003023009 -88.234465  40.114179  Block 3009  0.927051
# 18    170190106041242 -88.190166  40.142995  Block 1242  5.013334
# 19    170190106041116 -88.191286  40.152480  Block 1116  5.820392
# 20    170190106041088 -88.186139  40.158378  Block 1088  6.608211
# 21    170190106041262 -88.185371  40.153241  Block 1262  6.168402
# 22    170190056005066 -88.174448  40.088670  Block 5066  4.975215
